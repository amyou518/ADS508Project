# %% [markdown]
# # Upload Sample Images and Videos

# %%
import boto3
import sagemaker

sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()
bucket = sagemaker_session.default_bucket()
region = boto3.Session().region_name

sm = boto3.Session().client(service_name="sagemaker", region_name=region)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml

# %%
# copy data from our local media directory (github) into an S3 bucket
# !aws s3 cp --recursive ./media/ s3://$bucket/content-moderation/media/
# Out:
# upload: media/coffee.jpg to s3://sagemaker-us-east-1-975049898153/content-moderation/media/coffee.jpg
# upload: media/chris-antje.png to s3://sagemaker-us-east-1-975049898153/content-moderation/media/chris-antje.png
# upload: media/cars.png to s3://sagemaker-us-east-1-975049898153/content-moderation/media/cars.png
# upload: media/serverless-bytes.mov to s3://sagemaker-us-east-1-975049898153/content-moderation/media/serverless-bytes.mov
# upload: media/weapon.mp4 to s3://sagemaker-us-east-1-975049898153/content-moderation/media/weapon.mp4
# upload: media/hat-detection.png to s3://sagemaker-us-east-1-975049898153/content-moderation/media/hat-detection.png
# upload: media/GrandTourjc.png to s3://sagemaker-us-east-1-975049898153/content-moderation/media/GrandTourjc.png
# upload: media/GrandTour720.mp4 to s3://sagemaker-us-east-1-975049898153/content-moderation/media/GrandTour720.mp4
# upload: media/weapon.png to s3://sagemaker-us-east-1-975049898153/content-moderation/media/weapon.png

# %%
# !aws s3 ls s3://$bucket/content-moderation/media/
# Out:
# 2024-03-03 04:41:42    5321410 GrandTour720.mp4
# 2024-03-03 04:41:42    3453431 GrandTourjc.png
# 2024-03-03 04:41:42     998652 cars.png
# 2024-03-03 04:41:42     132849 chris-antje.png
# 2024-03-03 04:41:42     182226 coffee.jpg
# 2024-03-03 04:41:42     932907 hat-detection.png
# 2024-03-03 04:41:42    2270867 serverless-bytes.mov
# 2024-03-03 04:41:42     803874 weapon.mp4
# 2024-03-03 04:41:42    1214085 weapon.png

# %% [markdown]
# # Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
